# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('C://Users/86188/Desktop/Python Data/DATA/sammy_face.jpg')

# %%
plt.imshow(img)

# %%
# 确定双阈值，threshold1为下界，threshold2为上界
# 当图片的像素值大于上界则为边界，小于下界则舍弃，在两者中间若连接边界则为边界，否则舍弃
edges = cv2.Canny(image=img,threshold1=127,threshold2=127)

# %%
plt.imshow(edges)

# %%
med_val = np.median(img)

# %%
# LOWER THRESHOLD TO EITHER 0 OR 70% OF THE MEDIAN VALUE WHICHEVER IS GREATER
lower = int(max(0,0.7*med_val))
# UPPER THRESHOLD TO EITHER 130% OF THE MEDIAN VALUE OR 255 WHICHEVER IS GREATER
upper = int(min(255,1.3*med_val))

# %%
edges = cv2.Canny(image=img,threshold1=lower,threshold2=upper)

# %%
plt.imshow(edges)

# %%
blurred_img = cv2.blur(img,ksize=(5,5))

# %%
edges = cv2.Canny(image=blurred_img,threshold1=lower,threshold2=upper)
plt.imshow(edges)
