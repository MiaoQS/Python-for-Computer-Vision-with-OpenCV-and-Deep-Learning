# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#only for jupyter notebook

# %%
import cv2

# %%
img = cv2.imread('C://Users/86188/Desktop/Python Data/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#需要留意：当cv2.imread未读取到合适的文件时，会返回NoneType格式的属性类型，用于检测是否打开正确的图片

img = cv2.imread('It/does not exist/at all')
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('C://Users/86188/Desktop/Python Data/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

#cv2和matplotlib有不同的color channel，所以直接用一个去打开另一个导入的图片时会出现异常

# %%
#MATPLOTLIB --> RGB
#OPENCV --> BGR

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('C://Users/86188/Desktop/Python Data/DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
#按照一定比例对图片进行放缩
w_ratio = 0.5 #fifty percent of original picture
h_ratio = 0.5
new_img2 = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img2)

# %%
new_img2.shape
# Out:
# (650, 975, 3)

# %%
#0是倒转，1是镜像，-1是倒转叠加镜像

new_img3 = cv2.flip(fix_img,-1)
plt.imshow(new_img3)

# %%
cv2.imwrite('C://Users/86188/Desktop/Python Data/Test_Image/test.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
